# %% [markdown]
# ![스크린샷 2022-06-19 오후 11.41.37.png](data:image/png;base64,...)

# %%
from collections import Counter
n = int(input())
arr = []

for i in range(n):
    arr.append(input())

arr.sort()

counter = Counter(arr)

print(counter.most_common(n=1)[0][0])
# Out:
# 8
# icecream
# peanuts
# peanuts
# chocolate
# candy
# chocolate
# icecream
# apple
# chocolate
