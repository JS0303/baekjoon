# %% [markdown]
# ![스크린샷 2022-06-19 오후 11.42.29.png](data:image/png;base64,...)

# %%
doc = input()
word = input()
len_word = len(word)
count = 0
index = 0

while True:
    index = doc.find(word, index)
    if index == -1:
        break
    count += 1
    index += len_word

print(count)
# Out:
# aaaaaaa
# aa
# 3
