# %% [markdown]
# ![스크린샷 2022-06-19 오후 11.43.15.png](data:image/png;base64,...)

# %%
n = int(input())

count = 0
start = 1

while n > 0:
    if start > n: # 불러야 하는 음계가 남은 새의 수보다 많으면
        start = 1 # 1로 초기화
    n -= start    # 부른 음계만큼 새의 수 감소
    start += 1    # 새가 떠난 후 음계 +1
    count += 1

print(count)
# Out:
# 100
# 18
